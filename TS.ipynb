# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from Schubert import *
from TS import *
from helpers import *

# %%
# Initialise 2D schubert function
schubert_2d = Schubert(2)
x0 = np.array([[1],[1]]).astype('float64')
obj = schubert_2d.eval_obj
ts = TS(obj, x0)
x_opt, val, allx, r, its = ts.run()

# %%
schubert_2d.plot(opt=allx.T[:2,:], save="TS_2d_1_1", title='2D Tabu Search')

# %%
plot_min_err(allx.T[[-1],:], title='2D Tabu Search - {} evaluations'.format(its), save='ts_2d_1_1_minerr')

# %%
# Initialise 2D schubert function
schubert_5d = Schubert(5)
x0 = np.array([[1],[1],[1],[1],[1]]).astype('float64')
obj = schubert_5d.eval_obj
ts = TS(obj, x0)
x_opt, val, allx, r, its_5 = ts.run()

# %%
plot_min_err(allx.T[[-1],:], title='5D Tabu Search - {} evaluations'.format(its_5), save='ts_5d_1_1_minerr')

# %% [markdown]
# ## Investigating Parameters

# %%
div = np.array([1 + i for i in range(20)])
keywords = ['seed','diversify']
cl = TS
title = 'Investigating Effect of Varying Diversification Condition'
save = 'TS_div'
tuning_alg(cl, div, keywords, title, save)
# Out:
#  20/20%
#  20/20%

# %%
int_ = np.array([1 + i for i in range(15)])
keywords = ['seed','intensify']
cl = TS
title = 'Investigating Effect of Varying Intensification Condition'
save = 'TS_int'
tuning_alg(cl, int_, keywords, title, save)
# Out:
#  15/15%
#  15/15%

# %%
int_ = np.array([1 + i for i in range(35)])
keywords = ['seed','red']
cl = TS
title = 'Investigating Effect of Varying Step Reduction Condition'
save = 'TS_red'
tuning_alg(cl, int_, keywords, title, save)
# Out:
#  35/35%
#  35/35%

# %%
steps = np.linspace(0.1,2,20)
keywords = ['seed','step']
cl = TS
title = 'Investigating Effect of Varying Initial Step'
save = 'TS_step'
tuning_alg(cl, steps, keywords, title, save)
# Out:
#  20/20%
#  20/20%

# %%
stm = np.array([i + 1 for i in range(18)])
keywords = ['seed','stm_l']
cl = TS
title = 'Investigating Effect of Varying STM size'
save = 'TS_stm'
tuning_alg(cl, stm, keywords, title, save)
# Out:
#  18/18%
#  18/18%

# %%
mtm = np.array([i + 1 for i in range(18)])
keywords = ['seed','mtm_l']
cl = TS
title = 'Investigating Effect of Varying MTM size'
save = 'TS_mtm'
tuning_alg(cl, mtm, keywords, title, save)
# Out:
#  18/18%
#  18/18%

# %%
seed = np.array([i for i in range(30)])
keywords = ['seed','seed']
cl = TS
title = 'Investigating Random Variation'
save = 'TS_seed_opt'
tuning_alg(cl, seed, keywords, title, save)
# Out:
#  30/30%
#  30/30%

# %%
cl = TS
title = 'Investigating Effect of Different Starting Points'
save = 'TS_init_opt'
initialisation_effect(cl, title, save)
# Out:
#  40/40%
#  40/40%

# %%
seed = np.array([0.1,0.01,0.0001,0.00001])
keywords = ['seed','tol']
cl = TS
title = 'Investigating Change in Stopping Condition'
save = 'TS_tol'
tuning_alg(cl, seed, keywords, title, save, lg=True)
# Out:
#  4/4%
#  4/4%
